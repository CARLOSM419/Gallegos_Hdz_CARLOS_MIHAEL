# %% [markdown]
# <a href="https://colab.research.google.com/github/CARLOSM419/Gallegos_Hdz_CARLOS_MIHAEL/blob/main/Py_5_Carlos_Aseret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar pandas
import pandas as pd

# Cargar el archivo
reviews = pd.read_csv('/content/harvard_reviews.csv')

# ===== HISTORIA DE LOS DATOS =====
print(" HISTORIA DE LOS DATOS\n")

# usando iloc (selección por posición)

print(reviews.iloc[0:3][["published_date", "rating", "title"]])
print()

# Seleccionar  (posición 4)
print("🔹 Una reseña específica (fila 4 con iloc):")
print(reviews.iloc[4])
print()

# (por condición)
print("🔹 Reseñas con calificación perfecta (5 estrellas):")
perfectas = reviews.loc[reviews["rating"] == 5, ["published_date", "published_platform", "title"]]
print(perfectas.head())
print()

#  publicadas desde móviles
print("🔹 Opiniones publicadas desde celular:")
moviles = reviews.loc[reviews["published_platform"] == "Mobile", ["title", "rating"]]
print(moviles.head())
print()

#  texto nulo o vacío
print("🔹 Reseñas sin texto (isnull):")
vacias = reviews.loc[reviews["text"].isnull()]
print(vacias if not vacias.empty else "No hay reseñas vacías")
print()

# ===== HISTORIA  =====

print(f"Total: {len(reviews)}")
print(f"Promedio de calificación: {reviews['rating'].mean():.2f}")
print(f"Publicaciones desde móvil: {(reviews['published_platform'] == 'Mobile').sum()}")
print(f"Publicaciones desde escritorio: {(reviews['published_platform'] == 'Desktop').sum()}")

# %% [markdown]
# Harvard
#
# el conjunto de datos sobre Harvard University guarda un pequeño fragmento de la admiración, la curiosidad y la emoción de miles de personas que han conocido o soñado con conocer uno de los lugares más emblemáticos del mundo académico.
#
#  destacan frases como “Las mejores clases y un ambiente excelente” o “Caminar por el campus fue una experiencia increíble”. Esas palabras reflejan lo que muchos sienten al estar ahi: una mezcla de respeto por su historia y asombro por su belleza.
#
#  encontramos historias de visitantes que quedaron fascinados por los edificios antiguos y la arquitectura histórica. Algunos mencionan lo hermoso que resulta caminar entre los patios y bibliotecas, mientras otros resaltan la sensación de estar en un lugar lleno de conocimiento, donde grandes mentes han dejado su huella.
#
#  Los usuarios expresan gratitud y entusiasmo, lo que muestra que la mayoría de las experiencias fueron muy positivas. No solo admiran la universidad como institución educativa, sino también como un símbolo cultural y turístico.
#
# Una gran parte de las opiniones fue publicada desde dispositivos móviles, lo que nos hace imaginar a personas escribiendo sus comentarios en el momento mismo de la visita: quizás caminando por los jardines, tomando fotos frente a las estatuas o saliendo de un recorrido guiado, deseando compartir de inmediato lo que sintieron.
#
#  tienen texto. Esto indica que los visitantes no se limitaron a dar una calificación, sino que quisieron expresar con palabras su experiencia personal, ya sea breve o detallada.
#
# En conjunto, estas opiniones nos narran una historia de admiración, respeto y emoción. Harvard no solo representa excelencia académica, sino también un símbolo histórico y cultural que deja huella en quienes la conocen. Los datos nos hablan de un lugar que inspira, que transmite grandeza y que continúa siendo, para muchos, un destino de sueños y aprendizaje.

# %%
reviews.iloc[0:3]
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
#
#    helpful_votes                               title  \
# 0              0  Best classes and good environment
# 1              0                  Harvard University
# 2              0                  Walk around campus
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# 2  We did a walk around most of the Harvard Campu...

# %%
reviews.iloc[4]
# Out:
# published_date                                2023-10-02T17:40:42-04:00
# published_platform                                              Desktop
# rating                                                                5
# type                                                             review
# helpful_votes                                                         0
# title                 Lovely university campus has many historic and...
# text                  Finally made it to Harvard!!  This iconic univ...
# Name: 4, dtype: object

# %%
reviews.iloc[[0]]
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
#
#    helpful_votes                               title  \
# 0              0  Best classes and good environment
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...

# %%
reviews.iloc[:,0]
# Out:
# 0       2023-12-28T08:02:14-05:00
# 1       2023-12-12T00:38:26-05:00
# 2       2023-12-10T08:21:35-05:00
# 3       2023-11-07T21:20:21-05:00
# 4       2023-10-02T17:40:42-04:00
#                   ...
# 3179    2010-10-29T05:47:57-04:00
# 3180    2010-08-23T06:08:51-04:00
# 3181    2010-08-23T00:06:41-04:00
# 3182    2010-06-03T07:37:36-04:00
# 3183    2009-09-27T16:39:18-04:00
# Name: published_date, Length: 3184, dtype: object

# %%
reviews.iloc[:3,:3]
# Out:
#               published_date published_platform  rating
# 0  2023-12-28T08:02:14-05:00             Mobile       5
# 1  2023-12-12T00:38:26-05:00            Desktop       4
# 2  2023-12-10T08:21:35-05:00             Mobile       3

# %%
reviews.iloc[lambda fila: fila.index % 2 == 0]
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28T08:02:14-05:00             Mobile       5  review
# 2     2023-12-10T08:21:35-05:00             Mobile       3  review
# 4     2023-10-02T17:40:42-04:00            Desktop       5  review
# 6     2023-09-26T04:56:29-04:00            Desktop       5  review
# 8     2023-07-02T11:55:51-04:00            Desktop       4  review
# ...                         ...                ...     ...     ...
# 3174  2011-05-21T18:49:06-04:00            Desktop       4  review
# 3176  2011-04-06T06:32:32-04:00            Desktop       5  review
# 3178  2010-12-27T03:28:05-05:00            Desktop       5  review
# 3180  2010-08-23T06:08:51-04:00            Desktop       3  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# ...

# %%
reviews.iloc[[0,2],[1,3]]
# Out:
#   published_platform    type
# 0             Mobile  review
# 2             Mobile  review

# %%
reviews.iloc[-5:]
# Out:
#                  published_date published_platform  rating    type  \
# 3179  2010-10-29T05:47:57-04:00            Desktop       3  review
# 3180  2010-08-23T06:08:51-04:00            Desktop       3  review
# 3181  2010-08-23T00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27T16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 3179              0               amerikanischer campus fuer touristen
# 3180              0                               Weniger als erwartet
# 3181              0                              bellissima università
# 3182              2  Tolle Universität, definitiv einen Abstecher wert
# 3183              1                                            一度は行くべき
#
#                                                    text
# 3179  wenn man in boston ist hat manmeistens zeit au...
# ...

# %%
reviews.loc[reviews.published_date.notnull()]
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28T08:02:14-05:00             Mobile       5  review
# 1     2023-12-12T00:38:26-05:00            Desktop       4  review
# 2     2023-12-10T08:21:35-05:00             Mobile       3  review
# 3     2023-11-07T21:20:21-05:00            Desktop       4  review
# 4     2023-10-02T17:40:42-04:00            Desktop       5  review
# ...                         ...                ...     ...     ...
# 3179  2010-10-29T05:47:57-04:00            Desktop       3  review
# 3180  2010-08-23T06:08:51-04:00            Desktop       3  review
# 3181  2010-08-23T00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27T16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# ...

# %%
reviews.loc[reviews.published_platform.isnull()]
# Out:
# Empty DataFrame
# Columns: [published_date, published_platform, rating, type, helpful_votes, title, text]
# Index: []

# %%
reviews.loc[reviews.published_date.isnull()] = 0
reviews.loc[reviews.published_date == 0]
# Out:
# Empty DataFrame
# Columns: [published_date, published_platform, rating, type, helpful_votes, title, text]
# Index: []

# %%
reviews.shape
# Out:
# (3184, 7)
